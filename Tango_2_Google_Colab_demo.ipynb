# %% [markdown]
# # **Tango: LLM-guided Text-to-Audio Generation and DPO-based Alignment**

# %% [markdown]
# TANGO is a latent diffusion model (LDM) for text-to-audio (TTA) generation. TANGO can generate realistic audios including human sounds, animal sounds, natural and artificial sounds and sound effects from textual prompts. We use the frozen instruction-tuned LLM Flan-T5 as the text encoder and train a UNet based diffusion model for audio generation. We perform comparably to current state-of-the-art models for TTA across both objective and subjective metrics, despite training the LDM on a 63 times smaller dataset. We release our model, training, inference code, and pre-trained checkpoints for the research community.

# %%
# !git clone https://github.com/saravananbcs/tango.git
# Out:
# Cloning into 'tango'...
# remote: Enumerating objects: 2355, done.
# remote: Counting objects: 100% (341/341), done.
# remote: Compressing objects: 100% (195/195), done.
# remote: Total 2355 (delta 194), reused 259 (delta 143), pack-reused 2014
# Receiving objects: 100% (2355/2355), 18.34 MiB | 17.56 MiB/s, done.
# Resolving deltas: 100% (936/936), done.

# %%
# %cd /content/tango
# !pip install -r requirements.txt
# Out:
# /content/tango
# Collecting torch==1.13.1 (from -r requirements.txt (line 1))
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 2.0 MB/s eta 0:00:00
# Collecting torchaudio==0.13.1 (from -r requirements.txt (line 2))
#   Downloading torchaudio-0.13.1-cp310-cp310-manylinux1_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 95.4 MB/s eta 0:00:00
# Collecting torchvision==0.14.1 (from -r requirements.txt (line 3))
#   Downloading torchvision-0.14.1-cp310-cp310-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 59.0 MB/s eta 0:00:00
# Collecting transformers==4.27.0 (from -r requirements.txt (line 4))
#   Downloading transformers-4.27.0-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 95.9 MB/s eta 0:00:00
# Collecting accelerate==0.18.0 (from -r requirements.txt (line 5))
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 28.5 MB/s eta 0:00:00
# Collecting datasets==2.1.0 (from -r requirements.txt (line 6))
#   Downloading datasets-2.1.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.4/325.4 kB 38.0 MB/s eta 0:00:00
# Collecting diffusers==0.18.2 (from -r requirements.txt (line 7))
#   Downloading diffusers-0.18.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 81.6 MB/s eta 0:00:00
# Collecting einops==0.6.1 (from -r requirements.txt (line 8))
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.0 MB/s eta 0:00:00
# Collecting h5py==3.8.0 (from -r requirements.txt (line 9))
#   Downloading h5py-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 111.9 MB/s eta 0:00:00
# Collecting huggingface_hub==0.13.3 (from -r requirements.txt (line 10))
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 kB 28.5 MB/s eta 0:00:00
# Collecting importlib_metadata==6.3.0 (from -r requirements.txt (line 11))
#   Downloading importlib_metadata-6.3.0-py3-none-any.whl (22 kB)
# Collecting librosa==0.9.2 (from -r requirements.txt (line 12))
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 30.1 MB/s eta 0:00:00
# Collecting matplotlib==3.5.2 (from -r requirements.txt (line 13))
#   Downloading matplotlib-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 108.2 MB/s eta 0:00:00
# Collecting numpy==1.23.0 (from -r requirements.txt (line 14))
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 87.5 MB/s eta 0:00:00
# Collecting omegaconf==2.3.0 (from -r requirements.txt (line 15))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 12.1 MB/s eta 0:00:00
# Collecting packaging==23.1 (from -r requirements.txt (line 16))
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 7.5 MB/s eta 0:00:00
# Collecting pandas==1.4.1 (from -r requirements.txt (line 17))
#   Downloading pandas-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 103.2 MB/s eta 0:00:00
# Collecting progressbar33==2.4 (from -r requirements.txt (line 18))
#   Downloading progressbar33-2.4.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf==3.20.* in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 19)) (3.20.3)
# Collecting resampy==0.4.2 (from -r requirements.txt (line 20))
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 93.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit_image==0.19.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 21)) (0.19.3)
# Requirement already satisfied: scikit_learn==1.2.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 22)) (1.2.2)
# Collecting scipy==1.8.0 (from -r requirements.txt (line 23))
#   Downloading scipy-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: soundfile==0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 24)) (0.12.1)
# Collecting ssr_eval==0.0.6 (from -r requirements.txt (line 25))
#   Downloading ssr_eval-0.0.6-py3-none-any.whl (15 kB)
# Collecting torchlibrosa==0.1.0 (from -r requirements.txt (line 26))
#   Downloading torchlibrosa-0.1.0-py3-none-any.whl (11 kB)
# Collecting tqdm==4.63.1 (from -r requirements.txt (line 27))
#   Downloading tqdm-4.63.1-py2.py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 kB 11.5 MB/s eta 0:00:00
# Collecting wandb==0.12.14 (from -r requirements.txt (line 28))
#   Downloading wandb-0.12.14-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 97.4 MB/s eta 0:00:00
# Collecting ipython==8.12.0 (from -r requirements.txt (line 29))
#   Downloading ipython-8.12.0-py3-none-any.whl (796 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.4/796.4 kB 72.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->-r requirements.txt (line 1)) (4.11.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.1->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 77.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.1->-r requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.9 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.1->-r requirements.txt (line 1))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.1->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 78.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1->-r requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0->-r requirements.txt (line 4)) (3.13.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0->-r requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0->-r requirements.txt (line 4)) (2023.12.25)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.0->-r requirements.txt (line 4))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.7 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.18.0->-r requirements.txt (line 5)) (5.9.5)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.1.0->-r requirements.txt (line 6)) (14.0.2)
# Collecting dill (from datasets==2.1.0->-r requirements.txt (line 6))
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.4 MB/s eta 0:00:00
# Collecting xxhash (from datasets==2.1.0->-r requirements.txt (line 6))
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets==2.1.0->-r requirements.txt (line 6))
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.1.0->-r requirements.txt (line 6)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.1.0->-r requirements.txt (line 6)) (3.9.3)
# Collecting responses<0.19 (from datasets==2.1.0->-r requirements.txt (line 6))
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata==6.3.0->-r requirements.txt (line 11)) (3.18.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->-r requirements.txt (line 12)) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->-r requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->-r requirements.txt (line 12)) (4.4.2)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->-r requirements.txt (line 12)) (0.58.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2->-r requirements.txt (line 12)) (1.8.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->-r requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->-r requirements.txt (line 13)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->-r requirements.txt (line 13)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->-r requirements.txt (line 13)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.2->-r requirements.txt (line 13)) (2.8.2)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf==2.3.0->-r requirements.txt (line 15))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.1->-r requirements.txt (line 17)) (2023.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit_image==0.19.3->-r requirements.txt (line 21)) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit_image==0.19.3->-r requirements.txt (line 21)) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit_image==0.19.3->-r requirements.txt (line 21)) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_image==0.19.3->-r requirements.txt (line 21)) (1.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.2.2->-r requirements.txt (line 22)) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile==0.12.1->-r requirements.txt (line 24)) (1.16.0)
# Collecting wave (from ssr_eval==0.0.6->-r requirements.txt (line 25))
#   Downloading Wave-0.0.2.zip (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.14->-r requirements.txt (line 28)) (8.1.7)
# Collecting GitPython>=1.0.0 (from wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 29.9 MB/s eta 0:00:00
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.14->-r requirements.txt (line 28)) (2.3)
# Collecting shortuuid>=0.5.0 (from wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.12.14->-r requirements.txt (line 28)) (1.16.0)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading sentry_sdk-1.45.0-py2.py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 29.7 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0->-r requirements.txt (line 29)) (0.2.0)
# Collecting jedi>=0.16 (from ipython==8.12.0->-r requirements.txt (line 29))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0->-r requirements.txt (line 29)) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0->-r requirements.txt (line 29)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0->-r requirements.txt (line 29)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0->-r requirements.txt (line 29)) (2.16.1)
# Collecting stack-data (from ipython==8.12.0->-r requirements.txt (line 29))
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0->-r requirements.txt (line 29)) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0->-r requirements.txt (line 29)) (4.9.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements.txt (line 1)) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements.txt (line 1)) (0.43.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile==0.12.1->-r requirements.txt (line 24)) (2.22)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.1.0->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.1.0->-r requirements.txt (line 6)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.1.0->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.1.0->-r requirements.txt (line 6)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.1.0->-r requirements.txt (line 6)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.1.0->-r requirements.txt (line 6)) (4.0.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython>=1.0.0->wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython==8.12.0->-r requirements.txt (line 29)) (0.8.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa==0.9.2->-r requirements.txt (line 12)) (0.41.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython==8.12.0->-r requirements.txt (line 29)) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.2->-r requirements.txt (line 12)) (4.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.0->-r requirements.txt (line 29)) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->-r requirements.txt (line 3)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->-r requirements.txt (line 3)) (2024.2.2)
# Collecting executing>=1.2.0 (from stack-data->ipython==8.12.0->-r requirements.txt (line 29))
#   Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython==8.12.0->-r requirements.txt (line 29))
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Collecting pure-eval (from stack-data->ipython==8.12.0->-r requirements.txt (line 29))
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb==0.12.14->-r requirements.txt (line 28))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: progressbar33, antlr4-python3-runtime, pathtools, wave
#   Building wheel for progressbar33 (setup.py) ... done
#   Created wheel for progressbar33: filename=progressbar33-2.4-py3-none-any.whl size=12144 sha256=fa7e266267b526de0c0dcb4ff858160a690b28f3a5275e789662096b394bdbc2
#   Stored in directory: /root/.cache/pip/wheels/28/6d/b6/fd4b9b1489353528a2eea1200c98532fd60d535e22498d9e28
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=b9a950e92f330cec839061f465fc6ae027d9ce8365b24da6e1868efc691c1b3a
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=33de0f466dd33458f1ecef626a95a1b353e8987c4e4fec9a9e331fabd4300a1b
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
#   Building wheel for wave (setup.py) ... done
#   Created wheel for wave: filename=Wave-0.0.2-py3-none-any.whl size=1220 sha256=8e6b277f022c8fac86d875523550ae0a58bb9ed79294501967dceea8cfdac455
#   Stored in directory: /root/.cache/pip/wheels/f8/24/4d/1b01c0e32da3eb3fd71bbbc6093fcc557ec3b2d9e532ecd65d
# Successfully built progressbar33 antlr4-python3-runtime pathtools wave
# Installing collected packages: wave, tokenizers, pure-eval, progressbar33, pathtools, antlr4-python3-runtime, xxhash, tqdm, smmap, shortuuid, setproctitle, sentry-sdk, packaging, omegaconf, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, jedi, importlib_metadata, executing, einops, docker-pycreds, dill, asttokens, stack-data, scipy, responses, pandas, nvidia-cudnn-cu11, multiprocess, matplotlib, huggingface_hub, h5py, gitdb, transformers, torch, resampy, ipython, GitPython, diffusers, wandb, torchvision, torchaudio, librosa, datasets, accelerate, torchlibrosa, ssr_eval
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib_metadata 7.1.0
#     Uninstalling importlib_metadata-7.1.0:
#       Successfully uninstalled importlib_metadata-7.1.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.17.1+cu121
#     Uninstalling torchvision-0.17.1+cu121:
#       Successfully uninstalled torchvision-0.17.1+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.2.1+cu121
#     Uninstalling torchaudio-2.2.1+cu121:
#       Successfully uninstalled torchaudio-2.2.1+cu121
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.1
#     Uninstalling librosa-0.10.1:
#       Successfully uninstalled librosa-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.0.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.2 which is incompatible.
# bigframes 1.0.0 requires pandas>=1.5.0, but you have pandas 1.4.1 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.0 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 1.4.1 which is incompatible.
# jax 0.4.26 requires scipy>=1.9, but you have scipy 1.8.0 which is incompatible.
# jaxlib 0.4.26+cuda12.cudnn89 requires scipy>=1.9, but you have scipy 1.8.0 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.23.0 which is incompatible.
# plotnine 0.12.4 requires matplotlib>=3.6.0, but you have matplotlib 3.5.2 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.4.1 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# torchdata 0.7.1 requires torch>=2, but you have torch 1.13.1 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 1.13.1 which is incompatible.
# Successfully installed GitPython-3.1.43 accelerate-0.18.0 antlr4-python3-runtime-4.9.3 asttokens-2.4.1 datasets-2.1.0 diffusers-0.18.2 dill-0.3.8 docker-pycreds-0.4.0 einops-0.6.1 executing-2.0.1 gitdb-4.0.11 h5py-3.8.0 huggingface_hub-0.13.3 importlib_metadata-6.3.0 ipython-8.12.0 jedi-0.19.1 librosa-0.9.2 matplotlib-3.5.2 multiprocess-0.70.16 numpy-1.23.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 omegaconf-2.3.0 packaging-23.1 pandas-1.4.1 pathtools-0.1.2 progressbar33-2.4 pure-eval-0.2.2 resampy-0.4.2 responses-0.18.0 scipy-1.8.0 sentry-sdk-1.45.0 setproctitle-1.3.3 shortuuid-1.0.13 smmap-5.0.1 ssr_eval-0.0.6 stack-data-0.6.3 tokenizers-0.13.3 torch-1.13.1 torchaudio-0.13.1 torchlibrosa-0.1.0 torchvision-0.14.1 tqdm-4.63.1 transformers-4.27.0 wandb-0.12.14 wave-0.0.2 xxhash-3.4.1

# %%
# %cd /content/tango
import IPython
import soundfile as sf
from tango import Tango

tango = Tango("declare-lab/tango2")

prompt = "An audience cheering and clapping"
audio = tango.generate(prompt)
sf.write(f"{prompt}.wav", audio, samplerate=16000)
IPython.display.Audio(data=audio, rate=16000)
# Out:
# /content/tango
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# /content/tango/audioldm/audio/stft.py:42: FutureWarning: Pass size=1024 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   fft_window = pad_center(fft_window, filter_length)
# /content/tango/audioldm/audio/stft.py:151: FutureWarning: Pass sr=16000, n_fft=1024, n_mels=64, fmin=0, fmax=8000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_basis = librosa_mel_fn(
# UNet initialized randomly.
# Some weights of the model checkpoint at google/flan-t5-large were not used when initializing T5EncoderModel: ['decoder.block.1.layer.2.DenseReluDense.wi_0.weight', 'decoder.block.9.layer.0.SelfAttention.o.weight', 'decoder.block.16.layer.0.SelfAttention.k.weight', 'decoder.block.9.layer.0.SelfAttention.v.weight', 'decoder.block.16.layer.1.layer_norm.weight', 'decoder.block.10.layer.2.DenseReluDense.wi_1.weight', 'decoder.block.17.layer.0.layer_norm.weight', 'decoder.block.7.layer.2.DenseReluDense.wo.weight', 'decoder.block.11.layer.2.DenseReluDense.wo.weight', 'decoder.block.22.layer.2.DenseReluDense.wo.weight', 'decoder.block.18.layer.0.SelfAttention.q.weight', 'decoder.block.13.layer.2.DenseReluDense.wi_1.weight', 'decoder.block.2.layer.1.EncDecAttention.o.weight', 'decoder.block.7.layer.2.DenseReluDense.wi_0.weight', 'decoder.block.13.layer.0.layer_norm.weight', 'decoder.block.20.layer.0.SelfAttention.k.weight', 'decoder.block.0.layer.0.SelfAttention.v.weight', 'decoder.block.0.layer.0.SelfAttention.k.weight', 'decoder.block.17.layer.1.EncDecAttention.k.weight', 'decoder.block.14.layer.0.SelfAttention.o.weight', 'decoder.block.12.layer.0.SelfAttention.k.weight', 'decoder.block.16.layer.1.EncDecAttention.k.weight', 'decoder.block.18.layer.0.SelfAttention.k.weight', 'decoder.block.21.layer.2.DenseReluDense.wi_0.weight', 'decoder.block.12.layer.0.SelfAttention.v.weight', 'decoder.block.10.layer.2.DenseReluDense.wo.weight', 'decoder.block.19.layer.0.SelfAttention.v.weight', 'decoder.block.14.layer.1.EncDecAttention.o.weight', 'decoder.block.16.layer.1.EncDecAttention.o.weight', 'decoder.block.3.layer.0.SelfAttention.k.weight', 'decoder.block.23.layer.2.DenseReluDense.wi_0.weight', 'decoder.block.13.layer.0.SelfAttention.o.weight', 'decoder.block.17.layer.0.SelfAttention.o.weight', 'decoder.block.21.layer.0.SelfAttention.v.weight', 'decoder.block.7.layer.2.layer_norm.weight', 'decoder.block.4.layer.0.SelfAttention.v.weight', 'decoder.block.6.layer.1.layer_norm.weight', 'decoder.block.20.layer.1.EncDecAttention.o.weight', 'decoder.block.5.layer.1.EncDecAttention.v.weight', 'decoder.block.5.layer.1.EncDecAttention.q.weight', 'decoder.block.11.layer.1.EncDecAttention.o.weight', 'decoder.block.14.layer.2.DenseReluDense.wi_1.weight', 'decoder.block.20.layer.1.EncDecAttention.q.weight', 'decoder.block.12.layer.1.EncDecAttention.v.weight', 'decoder.block.6.layer.1.EncDecAttention.v.weight', 'decoder.block.21.layer.1.layer_norm.weight', 'decoder.block.16.layer.1.EncDecAttention.v.weight', 'decoder.block.14.layer.2.DenseReluDense.wo.weight', 'decoder.block.15.layer.0.SelfAttention.o.weight', 'decoder.block.7.layer.0.SelfAttention.o.weight', 'decoder.block.3.layer.2.DenseReluDense.wi_0.weight', 'decoder.block.3.layer.2.DenseReluDense.wo.weight', 'decoder.block.6.layer.2.DenseReluDense.wi_0.weight', 'decoder.block.9.layer.2.DenseReluDense.wi_1.weight', 'decoder.block.21.layer.0.SelfAttention.o.weight', 'decoder.block.2.layer.2.DenseReluDense.wi_1.weight', 'decoder.block.13.layer.2.layer_norm.weight', 'decoder.block.6.layer.1.EncDecAttention.o.weight', 'decoder.block.1.layer.0.SelfAttention.q.weight', 'decoder.block.14.layer.1.EncDecAttention.k.weight', 'decoder.block.12.layer.1.EncDecAttention.k.weight', 'decoder.block.17.layer.0.SelfAttention.v.weight', 'decoder.block.19.layer.0.SelfAttention.o.weight', 'decoder.block.18.layer.1.layer_norm.weight', 'decoder.block.11.layer.1.layer_norm.weight', 'decoder.block.14.layer.0.SelfAttention.k.weight', 'decoder.block.0.layer.0.SelfAttention.relative_attention_bias.weight', 'decoder.block.10.layer.0.SelfAttention.q.weight', 'decoder.block.20.layer.2.layer_norm.weight', 'decoder.block.14.layer.2.DenseReluDense.wi_0.weight', 'decoder.block.12.layer.0.SelfAttention.q.weight', 'decoder.block.7.layer.2.DenseReluDense.wi_1.weight', 'decoder.block.23.layer.2.DenseReluDense.wo.weight', 'decoder.block.19.layer.2.DenseReluDense.wo.weight', 'decoder.block.5.layer.0.SelfAttention.o.weight', 'decoder.block.22.l ...
# - This IS expected if you are initializing T5EncoderModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing T5EncoderModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Successfully loaded checkpoint from: declare-lab/tango2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prompt = "Rolling thunder with lightning strikes"
audio = tango.generate(prompt, steps=200)
IPython.display.Audio(data=audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prompts = [
    "A car engine revving",
    "A dog barks and rustles with some clicking",
    "Water flowing and trickling"
]
audios = tango.generate_for_batch(prompts, samples=2)
for audio_data in audios:
  IPython.display.Audio(data=audio, rate=16000)

# %% [markdown]
# Credits to the authors.
#
# ```
# @article{ghosal2023tango,
#   title={Text-to-Audio Generation using Instruction Tuned LLM and Latent Diffusion Model},
#   author={Ghosal, Deepanway and Majumder, Navonil and Mehrish, Ambuj and Poria, Soujanya},
#   journal={arXiv preprint arXiv:2304.13731},
#   year={2023}
# }
# ```
